# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
df_dailies=pd.read_csv('dailies_concat.csv')
df_sleeps=pd.read_csv('sleeps_concat.csv')
df_spo2=pd.read_csv('sleepSpo2_concat.csv')
df_level=pd.read_csv('levelsmap_concat.csv')
#df_hearteate=pd.read_csv('heartrate_concat.csv')
#檔案太大merge 不了
df_epochs=pd.read_csv('epochs_concat.csv')
df_activities=pd.read_csv('activities_concat.csv')

# %%
print('dailies',df_dailies.shape)
print('sleeps',df_sleeps.shape)
print('spo2',df_spo2.shape)
print('levelmap',df_level.shape)
#print('heartrate',df_hearteate.shape)
print('epochs',df_epochs.shape)
print('activities',df_activities.shape)
# Out:
# dailies (6301, 31)
# sleeps (5767, 12)
# spo2 (811593, 5)
# levelmap (119568, 6)
# epochs (348686, 15)
# activities (539, 19)

# %% [markdown]
# ## 空值處理 ##
# (未完)

# %%
#df_sleeps.isnull().sum()
df_dailies.isnull().sum()
# Out:
# activeKilocalories                       1
# activeTimeInSeconds                      1
# activityStressDurationInSeconds        305
# activityType                             1
# averageHeartRateInBeatsPerMinute       285
# averageStressLevel                       2
# bmrKilocalories                          1
# date                                  4132
# distanceInMeters                         1
# durationInSeconds                        1
# floorsClimbed                            1
# floorsClimbedGoal                        1
# highStressDurationInSeconds            971
# intensityDurationGoalInSeconds           1
# lowStressDurationInSeconds             350
# maxHeartRateInBeatsPerMinute           285
# maxStressLevel                         274
# mediumStressDurationInSeconds          470
# minHeartRateInBeatsPerMinute           285
# moderateIntensityDurationInSeconds       1
# id                                       0
# restStressDurationInSeconds            408
# restingHeartRateInBeatsPerMinute       277
# startTimeInSeconds                       1
# startTimeOffsetInSeconds                 1
# steps                                    1
# stepsGoal                                1
# stressDurationInSeconds                319
# stressQualifier                          2
# summaryId                                1
# vigorousIntensityDurationInSeconds       1
# dtype: int64

# %% [markdown]
# ### epoch+dailies=df_e_d ###

# %%
df_epochs=pd.read_csv('epochs_concat.csv')
df_dailies=pd.read_csv('dailies_concat.csv')
df_dailies['startTimeInSeconds'] = pd.to_datetime(df_dailies['startTimeInSeconds'],unit='s')
df_dailies=df_dailies.rename(columns={'startTimeInSeconds':'new_date'})
df_epochs['startTimeInSeconds'] = pd.to_datetime(df_epochs['startTimeInSeconds'],unit='s')
df_epochs=df_epochs.rename(columns={'startTimeInSeconds':'new_date'})
df_dailies['id']=df_dailies['id'].str.replace('dailies','')
df_epochs['id']=df_epochs['id'].str.replace('epochs','')
df_e_d=pd.merge(df_dailies,df_epochs,on=['id','new_date'],suffixes=('_dailies', '_epochs'))
df_e_d.drop(columns=['activityType_dailies'])
df_e_d=df_e_d.rename(columns={'activityType_epochs':'activityType'})
df_e_d=df_e_d.drop(columns=['summaryId_epochs'])
df_e_d=df_e_d.rename(columns={'summaryId_dailies':'summaryId'})
df_e_d=df_e_d.drop(columns=['activityType_dailies'])

# %% [markdown]
# /////////////////
# 以上別動
# ////////////////
# =========================

# %% [markdown]
# <font color=#FF6600> epochs+dailies<font color>
# ====

# %%
df_e_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7587 entries, 0 to 7586
# Data columns (total 42 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   activeKilocalories_dailies          7587 non-null   float64
#  1   activeTimeInSeconds_dailies         7587 non-null   float64
#  2   activityStressDurationInSeconds     7298 non-null   float64
#  3   averageHeartRateInBeatsPerMinute    7327 non-null   float64
#  4   averageStressLevel                  7587 non-null   float64
#  5   bmrKilocalories                     7587 non-null   float64
#  6   date_dailies                        2752 non-null   float64
#  7   distanceInMeters_dailies            7587 non-null   float64
#  8   durationInSeconds_dailies           7587 non-null   float64
#  9   floorsClimbed                       7587 non-null   float64
#  10  floorsClimbedGoal                   7587 non-null   float64
#  11  highStressDurationInSeconds         6570 non-null   float64
#  12  intensityDurationGoalInSeconds      7587 non-null   float64
#  13  lowStressDurationInSeconds          7252 non-null   float64
#  14  maxHeartRateInBeatsPerMinute        7327 non-null   float64
#  15  maxStressLevel                      7328 non-null   float64
#  16  mediumStressDurationInSeconds       7132 non-null   float64
#  17  minHeartRateInBeatsPerMinute        7327 non-null   float64
#  18  moderateIntensityDurationInSeconds  7587 non-null   float64
#  19  id                                  7587 non-null   object
#  20  restStressDurationInSeconds         7171 non-null   float64
#  21  restingHeartRateInBeatsPerMinute    7327 non-null   float64
#  22  new_date                            7587 non-null   datetime64[ns]
#  23  startTimeOffsetInSeconds_dailies    7587 non-null   float64
#  24  steps_dailies                       7587 non-null   float64
#  25  stepsGoal                           7587 non-null   float64
#  26  stressDurationInSeconds             7283 non-null   float64
#  27  stressQualifier                     7587 non-null   object
#  28  summaryId                           7587 non-null   object
#  29  vigorousIntensityDurationInSeconds  7587 non-null   float64
#  30  activeKilocalories_epochs           7587 non-null   float64
#  31  activeTimeInSeconds_epochs          7587 non-null   float64
#  32  activityType                        7587 non-null   object
#  33  date_epochs                         2752 non-null   float64
#  34  distanceInMeters_epochs             7587 non-null   float64
#  35  durationInSeconds_epochs            7587 non-null   float64
#  36  intensity                           7587 non-null   object
#  37  maxMotionIntensity                  7587 non-null   float64
#  38  meanMotionIntensity                 7587 non-null   float64
#  39  met                                 7587 non-null   float64
#  40  startTimeOffsetInSeconds_epochs     7587 non-null   float64
#  41  steps_epochs                        7587 non-null   float64
# dtypes: datetime64[ns](1), float64(36), object(5)
# memory usage: 2.5+ MB

# %%
df_e_d[['steps_dailies','steps_epochs']]
# Out:
#       steps_dailies  steps_epochs
# 0           10289.0           0.0
# 1             529.0           0.0
# 2           17175.0           0.0
# 3            1782.0          67.0
# 4            1782.0           0.0
# ...             ...           ...
# 7582         1435.0           0.0
# 7583          256.0          47.0
# 7584          256.0           0.0
# 7585         4702.0           0.0
# 7586         4702.0           0.0
#
# [7587 rows x 2 columns]

# %%
df_e_d['stepsGoal_complete?']=df_e_d['steps_dailies']/df_e_d['stepsGoal']
df_e_d['floorClimbed_complete?']=df_e_d['floorsClimbed']/df_e_d['floorsClimbedGoal']

# %%
test=df_e_d[['averageStressLevel','stressDurationInSeconds','steps_dailies','restStressDurationInSeconds',
'maxHeartRateInBeatsPerMinute','averageHeartRateInBeatsPerMinute','activeTimeInSeconds_dailies','activeKilocalories_dailies',
'vigorousIntensityDurationInSeconds','stepsGoal_complete?','floorClimbed_complete?']]
plt.figure(figsize=(8,8))
test.corr()
sns.heatmap(test.corr(),square=True,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 壓力大小分開

# %%
id_group=df_e_d.groupby('id')
print('幸福小鬼',id_group['averageStressLevel'].mean().sort_values().head())
print('壓力大的可憐人',id_group['averageStressLevel'].mean().sort_values().tail())
# Out:
# 幸福小鬼 id
# 1102_mr__10      7.463768
# 1102_mr__16     11.333333
# 1102_mrw__10    13.145299
# 1102_mrw__8     13.472727
# 1101_mr__1      18.015385
#                   ...
# 1102_mr__7      40.490566
# 1091_mr__3      40.924051
# 1101_mr__9      41.022727
# 1091_uty__14    42.357143
# 1102_mr__12     53.111111
# Name: averageStressLevel, Length: 82, dtype: float64
# 壓力大的可憐人 id
# 1102_mr__7      40.490566
# 1091_mr__3      40.924051
# 1101_mr__9      41.022727
# 1091_uty__14    42.357143
# 1102_mr__12     53.111111
# Name: averageStressLevel, dtype: float64

# %%
#顯著差異
_1102_mr__10=id_group.get_group('1102_mr__10')
_1102_mr__12 =id_group.get_group('1102_mr__12')

x=_1102_mr__10['averageHeartRateInBeatsPerMinute']
sns.kdeplot(x,label='幸福小鬼')
sns.set(style='dark')
sns.set_style("dark", {"axes.facecolor": "#e9f3ea"})
plt.style.use('ggplot')
x_2=_1102_mr__12['averageHeartRateInBeatsPerMinute']
sns.kdeplot(x_2,label='壓力大可憐仔')
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] 
plt.rcParams['axes.unicode_minus'] = False
plt.xlabel('平均心率')
plt.ylabel('')
plt.legend()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24179 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22343 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24515 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 29575 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24184 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 31119 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 23567 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 39740 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22739 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21147 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22823 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21487 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24976 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24179 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22343 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24515 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 29575 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24184 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 31119 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 23567 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 39740 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22739 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21147 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22823 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21487 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24976 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20180 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# stressDurationInSeconds=>在有壓力的狀況下的秒數(26~100) (重疊)<br>
# resStressDurationInSeconds=>無壓力狀況下的秒數(1~25)<br>
# activityStressDurationInSeconds=>(未被分類的時間)<br>
# lowStressDurationInSeconds=>壓力26~50的時間<br>
# mediumStressDurationInSecond=>壓力51~75的時間<br>
# highStressDurationInSeconds=>壓力76~100的時間<br>

# %%
#壓力小小人
_1102_mr__10=id_group.get_group('1102_mr__10')
_1102_mr__12 =id_group.get_group('1102_mr__12')
#define data
# stressDurationInSeconds
# restStressDurationInSeconds
# activityStressDurationInSeconds
# lowStressDurationInSeconds
# mediumStressDurationInSeconds
# highStressDurationInSeconds
data_x = _1102_mr__10[['restStressDurationInSeconds',
'activityStressDurationInSeconds','lowStressDurationInSeconds',
'mediumStressDurationInSeconds','highStressDurationInSeconds']]
labels = ['restStressDurationInSeconds',
'activityStressDurationInSeconds','lowStressDurationInSeconds',
'mediumStressDurationInSeconds','highStressDurationInSeconds']

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]
plt.title('壓力小小人的壓力分佈')
#create pie chart
plt.pie(data_x.mean(), labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %%
#壓力大大人
_1102_mr__10=id_group.get_group('1102_mr__10')
_1102_mr__12 =id_group.get_group('1102_mr__12')
#define data
# stressDurationInSeconds
# restStressDurationInSeconds
# activityStressDurationInSeconds
# lowStressDurationInSeconds
# mediumStressDurationInSeconds
# highStressDurationInSeconds
data_x = _1102_mr__12[['restStressDurationInSeconds',
'activityStressDurationInSeconds','lowStressDurationInSeconds',
'mediumStressDurationInSeconds','highStressDurationInSeconds']]
labels = ['restStressDurationInSeconds',
'activityStressDurationInSeconds','lowStressDurationInSeconds',
'mediumStressDurationInSeconds','highStressDurationInSeconds']
plt.title('壓力大大人的壓力分佈')
#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]

#create pie chart
plt.pie(data_x.mean(), labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# <font color=#FF6600>sleep<font color>
# ====

# %%
df_sleeps=pd.read_csv('sleeps_concat.csv')
df_level=pd.read_csv('levelsmap_concat.csv')
df_sleeps['id']=df_sleeps['id'].str.replace('sleeps','')
df_sleeps['startTimeInSeconds'] = pd.to_datetime(df_sleeps['startTimeInSeconds'],unit='s')
df_sleeps=df_sleeps.rename(columns={'startTimeInSeconds':'new_date'})

# %%
df_sleeps.date[df_sleeps.date=='2020-09-27']='927'
df_sleeps.date[df_sleeps.date=='2020-09-28']='928'
df_sleeps.date[df_sleeps.date=='2020-09-29']='929'
df_sleeps.date[df_sleeps.date=='2020-09-30']='930'
df_sleeps.date[df_sleeps.date=='2020-10-07']='1007'
df_sleeps.date[df_sleeps.date=='2020-10-16']='1016'
df_sleeps.date[df_sleeps.date=='2020-10-19']='1019'
df_sleeps.date[df_sleeps.date=='2020-10-20']='1020'
df_sleeps.date[df_sleeps.date=='2020-10-21']='1021'
df_sleeps.date[df_sleeps.date=='2020-10-22']='1022'
df_sleeps.date[df_sleeps.date=='2020-10-23']='1023'
df_sleeps.date[df_sleeps.date=='2020-10-25']='1025'
df_sleeps.date[df_sleeps.date=='2020-10-26']='1026'
df_sleeps.date[df_sleeps.date=='2020-10-27']='1027'
df_sleeps.date[df_sleeps.date=='2020-10-28']='1028'
df_sleeps.date[df_sleeps.date=='2020-10-29']='1029'
df_sleeps.date[df_sleeps.date=='2020-10-30']='1030'
df_sleeps.date[df_sleeps.date=='2020-10-15']='1015'
df_sleeps.date[df_sleeps.date=='2020-10-17']='1017'
df_sleeps.date[df_sleeps.date=='2020-10-18']='1018'
df_sleeps.date[df_sleeps.date=='2020-10-24']='1024'
df_sleeps.date[df_sleeps.date=='2020-10-31']='1031'
df_sleeps.date[df_sleeps.date=='2020-10-14']='1014'
df_sleeps.date[df_sleeps.date=='2020-09-26']='926'
df_sleeps.date[df_sleeps.date=='2020-10-06']='1006'
df_sleeps.date[df_sleeps.date=='2020-10-08']='1008'
df_sleeps.date[df_sleeps.date=='2020-10-10']='1010'
# Out:
# <ipython-input-17-1b7baea02372>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-09-27']='927'
# <ipython-input-17-1b7baea02372>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-09-28']='928'
# <ipython-input-17-1b7baea02372>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-09-29']='929'
# <ipython-input-17-1b7baea02372>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-09-30']='930'
# <ipython-input-17-1b7baea02372>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-07']='1007'
# <ipython-input-17-1b7baea02372>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-16']='1016'
# <ipython-input-17-1b7baea02372>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-19']='1019'
# <ipython-input-17-1b7baea02372>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-20']='1020'
# <ipython-input-17-1b7baea02372>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-21']='1021'
# <ipython-input-17-1b7baea02372>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-22']='1022'
# <ipython-input-17-1b7baea02372>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-23']='1023'
# <ipython-input-17-1b7baea02372>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-25']='1025'
# <ipython-input-17-1b7baea02372>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-26']='1026'
# <ipython-input-17-1b7baea02372>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-27']='1027'
# <ipython-input-17-1b7baea02372>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-28']='1028'
# <ipython-input-17-1b7baea02372>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-29']='1029'
# <ipython-input-17-1b7baea02372>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-30']='1030'
# <ipython-input-17-1b7baea02372>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-15']='1015'
# <ipython-input-17-1b7baea02372>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-17']='1017'
# <ipython-input-17-1b7baea02372>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-18']='1018'
# <ipython-input-17-1b7baea02372>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-24']='1024'
# <ipython-input-17-1b7baea02372>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-31']='1031'
# <ipython-input-17-1b7baea02372>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-14']='1014'
# <ipython-input-17-1b7baea02372>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-09-26']='926'
# <ipython-input-17-1b7baea02372>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-06']='1006'
# <ipython-input-17-1b7baea02372>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-08']='1008'
# <ipython-input-17-1b7baea02372>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sleeps.date[df_sleeps.date=='2020-10-10']='1010'

# %%
df_sleeps[df_sleeps.duplicated()==True]
df_sleeps.drop_duplicates(inplace=True,keep='first',subset=['new_date','date','id','summaryId',])
df_sleeps['date']=df_sleeps['date'].astype(float)

# %% [markdown]
# 以上為sleeps預處理
# ====

# %%
df_s_d=pd.merge(df_sleeps,df_dailies,on=['id','new_date'],suffixes=('_sleeps', '_dailies'))

# %%
df_s_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 0 to 43
# Data columns (total 41 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   awakeDurationInSeconds              44 non-null     float64
#  1   date_sleeps                         16 non-null     float64
#  2   deepSleepDurationInSeconds          44 non-null     float64
#  3   durationInSeconds_sleeps            44 non-null     float64
#  4   lightSleepDurationInSeconds         44 non-null     float64
#  5   id                                  44 non-null     object
#  6   remSleepInSeconds                   44 non-null     float64
#  7   new_date                            44 non-null     datetime64[ns]
#  8   startTimeOffsetInSeconds_sleeps     44 non-null     float64
#  9   summaryId_sleeps                    44 non-null     object
#  10  unmeasurableSleepInSeconds          44 non-null     float64
#  11  validation                          44 non-null     object
#  12  activeKilocalories                  44 non-null     float64
#  13  activeTimeInSeconds                 44 non-null     float64
#  14  activityStressDurationInSeconds     44 non-null     float64
#  15  activityType                        44 non-null     object
#  16  averageHeartRateInBeatsPerMinute    44 non-null     float64
#  17  averageStressLevel                  44 non-null     float64
#  18  bmrKilocalories                     44 non-null     float64
#  19  date_dailies                        16 non-null     float64
#  20  distanceInMeters                    44 non-null     float64
#  21  durationInSeconds_dailies           44 non-null     float64
#  22  floorsClimbed                       44 non-null     float64
#  23  floorsClimbedGoal                   44 non-null     float64
#  24  highStressDurationInSeconds         33 non-null     float64
#  25  intensityDurationGoalInSeconds      44 non-null     float64
#  26  lowStressDurationInSeconds          44 non-null     float64
#  27  maxHeartRateInBeatsPerMinute        44 non-null     float64
#  28  maxStressLevel                      44 non-null     float64
#  29  mediumStressDurationInSeconds       41 non-null     float64
#  30  minHeartRateInBeatsPerMinute        44 non-null     float64
#  31  moderateIntensityDurationInSeconds  44 non-null     float64
#  32  restStressDurationInSeconds         44 non-null     float64
#  33  restingHeartRateInBeatsPerMinute    44 non-null     float64
#  34  startTimeOffsetInSeconds_dailies    44 non-null     float64
#  35  steps                               44 non-null     float64
#  36  stepsGoal                           44 non-null     float64
#  37  stressDurationInSeconds             44 non-null     float64
#  38  stressQualifier                     44 non-null     object
#  39  summaryId_dailies                   44 non-null     object
#  40  vigorousIntensityDurationInSeconds  44 non-null     float64
# dtypes: datetime64[ns](1), float64(34), object(6)
# memory usage: 14.4+ KB

# %%
test=df_s_d[['averageStressLevel','restStressDurationInSeconds','stressDurationInSeconds','highStressDurationInSeconds',
'deepSleepDurationInSeconds','awakeDurationInSeconds','durationInSeconds_sleeps','lightSleepDurationInSeconds']]

test.corr()
sns.heatmap(test.corr(),square=True,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 深淺睡眠額外處理

# %%
data=pd.merge(df_sleeps,df_spo2,on=['summaryId','date'])
data=data.rename(columns={'id_x':'id'})
data=data.drop(columns=['id_y'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 763058 entries, 0 to 763057
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   awakeDurationInSeconds       763058 non-null  float64
#  1   date                         213146 non-null  float64
#  2   deepSleepDurationInSeconds   763058 non-null  float64
#  3   durationInSeconds            763058 non-null  float64
#  4   lightSleepDurationInSeconds  763058 non-null  float64
#  5   id                           763058 non-null  object
#  6   remSleepInSeconds            763058 non-null  float64
#  7   new_date                     763058 non-null  datetime64[ns]
#  8   startTimeOffsetInSeconds     763058 non-null  float64
#  9   summaryId                    763058 non-null  object
#  10  unmeasurableSleepInSeconds   763058 non-null  float64
#  11  validation                   763058 non-null  object
#  12  SleepSpo2                    763058 non-null  int64
#  13  timeseconds                  763058 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(2), object(3)
# memory usage: 87.3+ MB

# %%
data_mix=pd.merge(df_dailies,data,on=['id','new_date'])

# %%
data_mix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5508 entries, 0 to 5507
# Data columns (total 43 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   activeKilocalories                  5508 non-null   float64
#  1   activeTimeInSeconds                 5508 non-null   float64
#  2   activityStressDurationInSeconds     5508 non-null   float64
#  3   activityType                        5508 non-null   object
#  4   averageHeartRateInBeatsPerMinute    5508 non-null   float64
#  5   averageStressLevel                  5508 non-null   float64
#  6   bmrKilocalories                     5508 non-null   float64
#  7   date_x                              967 non-null    float64
#  8   distanceInMeters                    5508 non-null   float64
#  9   durationInSeconds_x                 5508 non-null   float64
#  10  floorsClimbed                       5508 non-null   float64
#  11  floorsClimbedGoal                   5508 non-null   float64
#  12  highStressDurationInSeconds         4241 non-null   float64
#  13  intensityDurationGoalInSeconds      5508 non-null   float64
#  14  lowStressDurationInSeconds          5508 non-null   float64
#  15  maxHeartRateInBeatsPerMinute        5508 non-null   float64
#  16  maxStressLevel                      5508 non-null   float64
#  17  mediumStressDurationInSeconds       4965 non-null   float64
#  18  minHeartRateInBeatsPerMinute        5508 non-null   float64
#  19  moderateIntensityDurationInSeconds  5508 non-null   float64
#  20  id                                  5508 non-null   object
#  21  restStressDurationInSeconds         5508 non-null   float64
#  22  restingHeartRateInBeatsPerMinute    5508 non-null   float64
#  23  new_date                            5508 non-null   datetime64[ns]
#  24  startTimeOffsetInSeconds_x          5508 non-null   float64
#  25  steps                               5508 non-null   float64
#  26  stepsGoal                           5508 non-null   float64
#  27  stressDurationInSeconds             5508 non-null   float64
#  28  stressQualifier                     5508 non-null   object
#  29  summaryId_x                         5508 non-null   object
#  30  vigorousIntensityDurationInSeconds  5508 non-null   float64
#  31  awakeDurationInSeconds              5508 non-null   float64
#  32  date_y                              967 non-null    float64
#  33  deepSleepDurationInSeconds          5508 non-null   float64
#  34  durationInSeconds_y                 5508 non-null   float64
#  35  lightSleepDurationInSeconds         5508 non-null   float64
#  36  remSleepInSeconds                   5508 non-null   float64
#  37  startTimeOffsetInSeconds_y          5508 non-null   float64
#  38  summaryId_y                         5508 non-null   object
#  39  unmeasurableSleepInSeconds          5508 non-null   float64
#  40  validation                          5508 non-null   object
#  41  SleepSpo2                           5508 non-null   int64
#  42  timeseconds                         5508 non-null   int64
# dtypes: datetime64[ns](1), float64(34), int64(2), object(6)
# memory usage: 1.8+ MB

# %% [markdown]
# 抓平均壓力大&小的人做spo2折線<br>
# spo2 分類?

# %%
test=data_mix[['averageStressLevel','restStressDurationInSeconds','stressDurationInSeconds','highStressDurationInSeconds',
'SleepSpo2','timeseconds','lightSleepDurationInSeconds']]

test.corr()
sns.heatmap(test.corr(),square=True,annot=True)
# Out:
# <AxesSubplot:>

# %%
df_spo2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811593 entries, 0 to 811592
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   SleepSpo2    811593 non-null  int64
#  1   date         261681 non-null  float64
#  2   id           811593 non-null  object
#  3   summaryId    811593 non-null  object
#  4   timeseconds  811593 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 31.0+ MB

# %% [markdown]
# 睡眠週期

# %%
sleeptime = df_s_d[['id','new_date','deepSleepDurationInSeconds','durationInSeconds_sleeps','lightSleepDurationInSeconds','remSleepInSeconds']]
sleeptime2 = df_s_d[['id','new_date','deepSleepDurationInSeconds','durationInSeconds_sleeps','lightSleepDurationInSeconds','remSleepInSeconds','averageStressLevel']]

# %%
sleeptime = sleeptime.drop_duplicates()
sleeptime = sleeptime.reset_index(drop = True)
sleeptime = sleeptime.reindex([9,5,8,7,10,0,1,2,6,4,3,11])
sleeptime = sleeptime.reset_index(drop= True)
print(sleeptime)
# Out:
#               id            new_date  deepSleepDurationInSeconds  \
# 0   1102_mrw__12 2022-03-20 16:00:00                      9900.0
# 1    1102_mr__13 2022-04-22 16:00:00                      4740.0
# 2    1102_mrw__1 2022-03-21 16:00:00                      3540.0
# 3    1102_mrw__1 2022-03-20 16:00:00                      6420.0
# 4    1102_mrw__2 2022-04-20 16:00:00                      2940.0
# 5    1091_uty__1 2020-10-26 16:00:00                      1380.0
# 6    1091_uty__1 2020-10-26 16:00:00                         0.0
# 7    1091_uty__3 2020-10-15 16:00:00                         0.0
# 8    1102_mr__14 2022-03-30 16:00:00                         0.0
# 9    1091_mr__13 2020-10-22 16:00:00                     12720.0
# 10   1091_mr__13 2020-10-21 16:00:00                         0.0
# 11   1092_mr__11 2020-05-28 16:00:00                     11220.0
#
#     durationInSeconds_sleeps  lightSleepDurationInSeconds  remSleepInSeconds
# 0                    28500.0                      18600.0                0.0
# 1                    28920.0                      16560.0             7620.0
# 2                    23280.0                      17100.0             2640.0
# 3                    22140.0                      12000.0             3720.0
# 4                    24480.0                      15540.0             3540.0
# 5                    30420.0                      20820.0             8220.0
# 6                    34080.0                      24900.0             9180.0
# 7                    30540.0                      16620.0            13080.0
# 8                    42960.0                      34440.0             7680.0
# 9                    29400.0                      16680.0                0.0
# 10                   33240.0                      23400.0             9840.0
# 11                   23160.0                      11940.0                0.0

# %%
deepsleep = []
lightsleep = []
remsleep = []
for i in range(len(sleeptime)):
    a = sleeptime["durationInSeconds_sleeps"].at[i]
    b = sleeptime["deepSleepDurationInSeconds"].at[i]
    c = sleeptime["lightSleepDurationInSeconds"].at[i]
    d = sleeptime["remSleepInSeconds"].at[i]
    deep = (b/a)*100
    deepsleep.append(deep)
    light = (c/a)*100
    lightsleep.append(light)
    rem = (d/a)*100
    remsleep.append(rem)
sleeptime.insert(6, column="deepSleep_per", value=deepsleep)
sleeptime.insert(7, column="lightSleep_per", value=lightsleep)
sleeptime.insert(8, column="remSleep_per", value=remsleep)

# %%
sleeptime = sleeptime.drop([3,4,5,6,7,9])
sleeptime = sleeptime.reset_index(drop= True)
sleeptime
# Out:
#              id            new_date  deepSleepDurationInSeconds  \
# 0  1102_mrw__12 2022-03-20 16:00:00                      9900.0
# 1   1102_mr__13 2022-04-22 16:00:00                      4740.0
# 2   1102_mrw__1 2022-03-21 16:00:00                      3540.0
# 3   1102_mr__14 2022-03-30 16:00:00                         0.0
# 4   1091_mr__13 2020-10-21 16:00:00                         0.0
# 5   1092_mr__11 2020-05-28 16:00:00                     11220.0
#
#    durationInSeconds_sleeps  lightSleepDurationInSeconds  remSleepInSeconds  \
# 0                   28500.0                      18600.0                0.0
# 1                   28920.0                      16560.0             7620.0
# 2                   23280.0                      17100.0             2640.0
# 3                   42960.0                      34440.0             7680.0
# 4                   33240.0                      23400.0             9840.0
# 5                   23160.0                      11940.0                0.0
#
#    deepSleep_per  lightSleep_per  remSleep_per
# 0      34.736842       65.263158      0.000000
# 1      16.390041       57.261411     26.348548
# 2      15.206186       73.453608     11.340206
# 3       0.000000       80.167598     17.877095
# 4       0.000000       70.397112     29.602888
# 5      48.445596       51.554404      0.000000

# %%
id_group2=sleeptime2.groupby('id')
print(id_group2['averageStressLevel'].mean().sort_values())
#print(sleeptime2)
# Out:
# id
# 1102_mrw__12    13.600000
# 1102_mr__13     16.333333
# 1102_mrw__1     18.200000
# 1102_mrw__2     20.800000
# 1091_uty__1     22.333333
# 1091_uty__3     23.000000
# 1102_mr__14     24.800000
# 1091_mr__13     33.400000
# 1092_mr__11     34.500000
# Name: averageStressLevel, dtype: float64

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
r = [0,1,2,3,4,5]
totals = [i+j+k for i,j,k in zip(sleeptime['deepSleep_per'], sleeptime['lightSleep_per'], sleeptime['remSleep_per'])]
deep_ = [i / j * 100 for i,j in zip(sleeptime['deepSleep_per'], totals)]
light_ = [i / j * 100 for i,j in zip(sleeptime['lightSleep_per'], totals)]
rem_ = [i / j * 100 for i,j in zip(sleeptime['remSleep_per'], totals)]

barWidth = 0.85
plt.bar(r, deep_, color='#2B3467', edgecolor='white', width=barWidth)
plt.bar(r, light_, bottom=deep_, color='#BAD7E9', edgecolor='white', width=barWidth)
plt.bar(r, rem_, bottom=[i+j for i,j in zip(deep_, light_)], color='#F0E9D2', edgecolor='white', width=barWidth)
plt.xlabel("stressless <----------------------> stressful")

plt.show()
